# %%
import plotly.express as px
import numpy as np 
import pandas as pd
import plotly.graph_objs as go

# %%
import pandas as pd
df = pd.read_pickle("D:\\Temp\\epp_final\\bld\\python\\data\\data_modify.pickle")
nwdf = df.loc[(df['treatment']== "1.1") | (df['treatment']== "1.2") | (df['treatment']== "1.3")| (df['treatment']== "2")]
#1.1 1 piece rate
#1.2 10 piece rate
#1.3 No piece rate
#1.4 very very low piece rate

# %%
#nwdf = df[df['treatment']=="1.1"&df['treatment']=="1.2"]
fig = px.ecdf(nwdf, x="buttonpresses",color="treatment", markers=True, marginal="histogram")
fig.show()

# %%
nwdf = df.loc[(df['treatment']== "1.1") | (df['treatment']== "3.1") | (df['treatment']== "3.2")]
fig = px.ecdf(nwdf, x="buttonpresses",color="treatment", markers=True, marginal="histogram")
fig.show()

# %%
nwdf = df.loc[(df['treatment']== "1.1") | (df['treatment']== "4.1") | (df['treatment']== "4.2")]
fig = px.ecdf(nwdf, x="buttonpresses",color="treatment", markers=True, marginal="histogram")
fig.show()

# %%
nwdf = df.loc[(df['treatment']== "1.1") | (df['treatment']== "5.1") | (df['treatment']== "5.2")|(df['treatment']== "5.3")]#可以重複寫
fig = px.ecdf(nwdf, x="buttonpresses",color="treatment", markers=True, marginal="histogram")
fig.show()

# %%
nwdf = df.loc[(df['treatment']== "1.1") | (df['treatment']== "6.1") | (df['treatment']== "6.2")|(df['treatment']== "6.1")]#可以重複寫
fig = px.ecdf(nwdf, x="buttonpresses",color="treatment", markers=True, marginal="histogram")
fig.show()

# %%
nwdf = df.loc[(df['treatment']== "1.1") | (df['treatment']== "7") | (df['treatment']== "8")|(df['treatment']== "9")]#可以重複寫
fig = px.ecdf(nwdf, x="buttonpresses",color="treatment", markers=True, marginal="histogram")
fig.show()

# %%
dff = pd.read_stata('D:\\Temp\\mturk_clean_data_short.dta')
emp_mean = dff.groupby("treatment").mean()
emp_std = dff.groupby("treatment").std()
emp_count = dff.groupby("treatment").count()
CI_range = (emp_std['buttonpresses']*1.96)/np.sqrt(emp_count['buttonpresses']-1)
CI_upper = emp_mean['buttonpresses']+(CI_range)
CI_lower = emp_mean['buttonpresses']-np.array(CI_range)
CI_upper
# Out:
# C:\Users\ua896\AppData\Local\Temp\ipykernel_79208\2701708574.py:2: FutureWarning:
#
# The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#
# C:\Users\ua896\AppData\Local\Temp\ipykernel_79208\2701708574.py:3: FutureWarning:
#
# The default value of numeric_only in DataFrameGroupBy.std is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
# treatment
# 1.1    2083.333701
# 1.2    2222.258237
# 1.3    1581.941231
# 1.4    2183.679264
# 10     1660.296203
# 2      1939.324467
# 3.1    1959.675906
# 3.2    1969.286720
# 4.1    2057.927185
# 4.2    2026.620520
# 5.1    2184.326649
# 5.2    2200.064769
# 5.3    2232.954996
# 6.1    1951.324762
# 6.2    2025.665164
# 7      1911.425845
# 8      1821.389037
# ...

# %%
treat = ["1c PieceRate","10c PieceRate","No Payment","4c PieceRate","Gift_exchange","Very Low Pay","1c RedCross","10c RedCross","1c 2Wks","1c 4Wks","Gain 40c"
 ,"Loss 40c","Gain 80c","Prob.01 $1","Prob.5 2c","Social Comp","Ranking","Task Signif"]

# %%
fig = go.Figure([
    go.Scatter(
        name='Mean_Button_Press',
        x=treat,
        y=emp_mean['buttonpresses'],
        mode='lines',
        line=dict(color='rgb(31, 119, 180)'),
        
    ),
    go.Scatter(
        name='Upper Bound',
        x=treat,
        y=emp_mean['buttonpresses']+np.array(CI_range),
        mode='lines',
        marker=dict(color="#444"),
        line=dict(width=0),
        showlegend=False
    ),
    go.Scatter(
        name='Lower Bound',
        x=treat,
        y=emp_mean['buttonpresses']-np.array(CI_range),
        marker=dict(color="#444"),
        line=dict(width=0),
        mode='lines',
        fillcolor='rgba(68, 68, 68, 0.3)',
        fill='tonexty',
        showlegend=False
    )
])
fig.update_layout(
    yaxis_title='Button_Press(Effort)',
    title='Effort correspond to each treatment',
    hovermode="x"
)
fig.show()
